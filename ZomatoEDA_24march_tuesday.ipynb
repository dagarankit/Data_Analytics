# %%
import pandas as pd

# %%
data=pd.read_csv('F:\ML\zomato\zomato.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
# url                            51717 non-null object
# address                        51717 non-null object
# name                           51717 non-null object
# online_order                   51717 non-null object
# book_table                     51717 non-null object
# rate                           43942 non-null object
# votes                          51717 non-null int64
# phone                          50509 non-null object
# location                       51696 non-null object
# rest_type                      51490 non-null object
# dish_liked                     23639 non-null object
# cuisines                       51672 non-null object
# approx_cost(for two people)    51371 non-null object
# reviews_list                   51717 non-null object
# menu_item                      51717 non-null object
# listed_in(type)                51717 non-null object
# listed_in(city)                51717 non-null object
# dtypes: int64(1), object(16)
# memory usage: 6.7+ MB

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
data.shape
# Out:
# (51717, 17)

# %%
data.isna().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
data["online_order"].value_counts()
# Out:
# Yes    30444
# No     21273
# Name: online_order, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
sns.set_style('darkgrid')
chains= data['name'].value_counts()[:20]
#online= df['']
sns.barplot(x= chains, y = chains.index, palette= 'dark')
sns.despine()
plt.title('Top 20 restaurant chains in Bangaluru')
plt.xlabel('Number of outlets')
plt.ylabel('Name of Restaurants')
# Out:
# Text(0, 0.5, 'Name of Restaurants')

# %%
chains
# Out:
# Cafe Coffee Day      96
# Onesta               85
# Just Bake            73
# Empire Restaurant    71
# Five Star Chicken    70
# Kanti Sweets         68
# Petoo                66
# Polar Bear           65
# Baskin Robbins       64
# Pizza Hut            62
# Chef Baker's         62
# Domino's Pizza       60
# Sweet Truth          60
# KFC                  60
# Beijing Bites        60
# Subway               60
# McDonald's           59
# Smoor                59
# Chai Point           58
# Faasos               57
# Name: name, dtype: int64

# %%
chains.index #Cafee Cofee Day has the most number of outlets in the city of bangaluru. McDonald's is on the 17th number according to number of outlets.
# Out:
# Index(['Cafe Coffee Day', 'Onesta', 'Just Bake', 'Empire Restaurant',
#        'Five Star Chicken', 'Kanti Sweets', 'Petoo', 'Polar Bear',
#        'Baskin Robbins', 'Pizza Hut', 'Chef Baker's', 'Domino's Pizza',
#        'Sweet Truth', 'KFC', 'Beijing Bites', 'Subway', 'McDonald's', 'Smoor',
#        'Chai Point', 'Faasos'],
#       dtype='object')

# %%
data['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 51717, dtype: object

# %%
data['rate'].isna().sum()
# Out:
# 7775

# %%
data['rate']=data['rate'].astype(str)

# %%
data['rate']=data['rate'].apply(lambda r:r.replace('/5',''))

# %%
data['rate'][:5]
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: object

# %%
newdata=data['rate'][:5]

# %%
newdata.min()
# Out:
# '3.7'

# %%
dmax=newdata.max()
dmax
# Out:
# '4.1'

# %%
data[data['rate']==dmax ]['location']
# Out:
# 0                 Banashankari
# 1                 Banashankari
# 10                Banashankari
# 51                 Vijay Nagar
# 65                Basavanagudi
#                  ...
# 28210    Koramangala 7th Block
# 28216    Koramangala 6th Block
# 28243    Koramangala 6th Block
# 28269                      HSR
# 28271                   Domlur
# Name: location, Length: 1474, dtype: object

# %%
data['book_table'].value_counts()
# Out:
# No     45268
# Yes     6449
# Name: book_table, dtype: int64

# %%
#No of restaurants with table booking capacity
(data.book_table == 'Yes').sum()
# Out:
# 6449

# %%
data['book_table']
# Out:
# 0        Yes
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 51712     No
# 51713     No
# 51714     No
# 51715    Yes
# 51716     No
# Name: book_table, Length: 51717, dtype: object

# %%
(data.book_table == 'No').sum()
# Out:
# 45268

# %%
x=data['book_table']
sns.countplot(x)

# %%
sns.countplot(x=data['book_table'],hue=data['listed_in(type)'])

# %%
data['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5',
#        'nan', '2.6', '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4',
#        '2.2', '2.3', '3.4 ', '-', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ',
#        '4.1 ', '3.7 ', '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ',
#        '2.5 ', '3.2 ', '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1',
#        '2.0', '1.8', '4.6 ', '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ',
#        '2.4 ', '2.1 ', '2.2 ', '2.0 ', '1.8 '], dtype=object)

# %%
print("Number of restaurents rating between 1.5 and 2")
((newdata>=1.5) & (newdata<2)).sum()
# Out:
# Number of restaurents rating between 1.5 and 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-f0d92620808c> in <module>
#       1 print("Number of restaurents rating between 1.5 and 2")
# ----> 2 ((newdata>=1.5) & (newdata<2)).sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'float'

# %%
data.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
data['rate']=data.loc[:,'rate'].replace('[ ]','',regex=True)
data['rate']=data['rate'].astype(str)
data['rate']=data['rate'].apply(lambda r:r.replace('/5',''))
data['rate']=data['rate'].apply(lambda r:float(r))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-5d3581d91d6e> in <module>
#       2 data['rate']=data['rate'].astype(str)
#       3 data['rate']=data['rate'].apply(lambda r:r.replace('/5',''))
# ----> 4 data['rate']=data['rate'].apply(lambda r:float(r))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-85-5d3581d91d6e> in <lambda>(r)
#       2 data['rate']=data['rate'].astype(str)
#       3 data['rate']=data['rate'].apply(lambda r:r.replace('/5',''))
# ----> 4 data['rate']=data['rate'].apply(lambda r:float(r))
#
# ValueError: could not convert string to float: 'NEW'

# %%
import numpy as np
data['rate']=data['rate'].replace('NEW',np.NAN)
data['rate']=data['rate'].replace('-',np.NAN)
data.dropna(how='any',inplace=True)

# %%
data['rate']=data.loc[:,'rate'].replace('[ ]','',regex=True)
data['rate']=data['rate'].astype(str)
data['rate']=data['rate'].apply(lambda r:r.replace('/5',''))
data['rate']=data['rate'].apply(lambda r:float(r))

# %%
print("Number of restaurents rating between 1.5 and 2")
((data.rate>=1.5) & (data.rate<2)).sum()
# Out:
# Number of restaurents rating between 1.5 and 2
# 5

# %%
#plotting pie chart
slices=[((data.rate>=1.5) & (data.rate<2)).sum(),
        ((data.rate>=2) & (data.rate<2.5)).sum(),
        ((data.rate>=2.5) & (data.rate<3)).sum(),
        ((data.rate>=3.0) & (data.rate<3.5)).sum(),
        ((data.rate>=3.5) & (data.rate<4)).sum(),
        ((data.rate>=4) & (data.rate<4.5)).sum(),
        ((data.rate>=4.5) & (data.rate<5)).sum()
       ]
labels=['1.5-2','2-2.5','2.5-3','3-3.5','3.5-4','4-4.5','4.5-5']
colors = ['Red','blue','Green','black','orange','pink']
explode=[0,0,0,0,1,1,0.5]
plt.pie(slices,colors=colors, labels=labels, autopct='%1.0f%%',explode=explode)
fig = plt.gcf()
plt.title("Percentage of Restaurants according to their ratings")

fig.set_size_inches(5,5)
plt.show()

# %%
#q1 Analysis of Restaurants based on their online order and how rating is related to it
#q2 ANALYSIS OF RESTAURENTS BASED ON THEIR LOCATION

# %%
print("count of restaurents at unique locations")
locationCount=data['location'].value_counts().sort_values(ascending=True)
locationCount
# Out:
# count of restaurents at unique locations
# KR Puram                    1
# West Bangalore              2
# Rajarajeshwari Nagar        2
# Kanakapura Road             2
# Magadi Road                 2
#                          ...
# Jayanagar                1040
# HSR                      1155
# Indiranagar              1334
# BTM                      1450
# Koramangala 5th Block    1761
# Name: location, Length: 88, dtype: int64

# %%
dt=data['location'].value_counts()[0:10]
import seaborn as sns
plt.figure(figsize=(20,5))
sns.set_style('darkgrid')
sns.barplot(x=dt.index,y=dt,palette="dark",hue=dt.index)

# %%
fig=plt.figure(figsize=(20,40))
locationCount.plot(kind="barh",fontsize=20) # barh for representing horizontal bar
plt.ylabel("Location names",fontsize=50,color="red",fontweight='bold')
plt.title("LOCATION VS RESTAURANT COUNT GRAPH",fontsize=40,color="BLACK")
plt.show()

# %%
data['location'].nunique()
# Out:
# 88

# %%
print('Count of all different dinning type restaurents')
restaurantTypeCount=data['listed_in(type)'].value_counts().sort_values(ascending=True)
restaurantTypeCount
# Out:
# Count of all different dinning type restaurents
# Pubs and bars           517
# Buffet                  753
# Drinks & nightlife      871
# Cafes                  1046
# Desserts               1330
# Dine-out               7980
# Delivery              10578
# Name: listed_in(type), dtype: int64

# %%
print('all different dinning type of restaurents')
data['listed_in(type)'].unique()
# Out:
# all different dinning type of restaurents
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'], dtype=object)

# %%
#Analysis on the basis of food type

data['cuisines'].str.findall('North Indian').value_counts()
# Out:
# []                30587
# [North Indian]    21085
# Name: cuisines, dtype: int64

# %%
(data['cuisines']=='North Indian').sum()
# Out:
# 1136

# %%
NorthIndianFoodRestaurants = data[data['cuisines'].str.contains('North Indian', case=False, regex=True,na=False)]
NorthIndianFoodRestaurants.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...        Timepass Dinner
#
#   online_order book_table rate  votes                             phone  \
# 0          Yes        Yes  4.1    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1    787                      080 41714161
# 3           No         No  3.7     88                    +91 9620009302
# 4           No         No  3.8    166  +91 8026612447\r\n+91 9901210005
# 5          Yes         No  3.8    286  +91 9980040002\r\n+91 9980063005
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
# 3  Banashankari    Quick Bites
# 4  Basavanagudi  Casual Dining
# 5  Basavanagudi  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
# 5  Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
# 5                    North Indian                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# 5  [('Rated 3.0', 'RATED\n  Food 3/5\nAmbience 3/...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari
# 5          Buffet    Banashankari

# %%
NorthIndianFoodRestaurants = data[data['cuisines'].str.contains('North Indian', case=False, regex=True,na=False)]
#NorthIndianFoodRestaurants.head()
NorthIndianFoodRestaurants['name'].nunique()
# Out:
# 1534

# %%
SouthIndianFoodRestaurants = data[data['cuisines'].str.contains('South Indian', case=False, regex=True,na=False)]
#NorthIndianFoodRestaurants.head()
SouthIndianFoodRestaurants["name"].nunique()
# Out:
# 522

# %%
ChineseFoodRestaurants = data[data['cuisines'].str.contains('Chinese|Momos', case=False, regex=True,na=False)]
ChineseFoodRestaurants['name'].nunique()
# Out:
# 1178

# %%
ItalianFoodRestaurants = data[data['cuisines'].str.contains('Italian|Pizza', case=False, regex=True,na=False)]
ItalianFoodRestaurants['name'].nunique()
# Out:
# 410

# %%
MexicanFoodRestaurants = data[data['cuisines'].str.contains('Mexican', case=False, regex=True,na=False)]
MexicanFoodRestaurants['name'].nunique()
# Out:
# 44

# %%
AmericanFoodRestaurants = data[data['cuisines'].str.contains('american|Burger', case=False, regex=True,na=False)]
AmericanFoodRestaurants['name'].nunique()
# Out:
# 232

# %%
ChineseFoodRestaurants = data[data['cuisines'].str.contains('Chinese|Momos', case=False, regex=True,na=False)]
ChineseFoodRestaurants['name'].nunique()
#ChineseFoodRestaurants.info()
# Out:
# 1178
