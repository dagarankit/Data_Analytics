# %%
import pandas as pd

# %%
df=pd.read_csv('F:/ML/CLASS_NOTES/advertising.csv')

# %%
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
df.rename(columns={"Daily Time Spent on Site":" DTSOS"})
# Out:
#       DTSOS  Age  Area Income  Daily Internet Usage  \
# 0     68.95   35     61833.90                256.09
# 1     80.23   31     68441.85                193.77
# 2     69.47   26     59785.94                236.50
# 3     74.15   29     54806.18                245.89
# 4     68.37   35     73889.99                225.58
# ..      ...  ...          ...                   ...
# 995   72.97   30     71384.57                208.58
# 996   51.30   45     67782.17                134.42
# 997   51.63   51     42415.72                120.37
# 998   55.55   19     41920.79                187.95
# 999   45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# 0       Cloned 5thgeneration orchestration     Wrightburgh     0
# 1       Monitored national standardization       West Jodi     1
# 2         Organic bottom-line service-desk        Davidton     0
# 3    Triple-buffered reciprocal time-frame  West Terrifurt     1
# ...

# %%
df.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
df.drop('Ad Topic Line',axis=1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                City  Male                 Country            Timestamp  \
# ...

# %%
df.drop('Country',axis=1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
df.drop('City',axis=1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line  Male                 Country  \
# ...

# %%
df.drop('Timestamp',axis=1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
df.drop('City',axis=1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line  Male                 Country  \
# ...

# %%
X=df.drop('Clicked on Ad',axis=1)

# %%
y=df['Clicked on Ad']

# %%
dfy=df.iloc[:,0]

# %%
dfy
# Out:
# 0      68.95
# 1      80.23
# 2      69.47
# 3      74.15
# 4      68.37
#        ...
# 995    72.97
# 996    51.30
# 997    51.63
# 998    55.55
# 999    45.01
# Name: Daily Time Spent on Site, Length: 1000, dtype: float64

# %%
dfx=df.iloc[1:2]

# %%
dfx
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 1                     80.23   31     68441.85                193.77
#
#                         Ad Topic Line       City  Male Country  \
# 1  Monitored national standardization  West Jodi     1   Nauru
#
#              Timestamp  Clicked on Ad
# 1  2016-04-04 01:39:02              0

# %%
df.drop(['Country','City','Ad Topic Line','Timestamp'],axis=1,inplace=True)

# %%
X=df.iloc[:[1,2,3,5]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-301af3dd488a> in <module>
# ----> 1 X=df.iloc[:[1,2,3,5]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2135     def _getitem_axis(self, key, axis: int):
#    2136         if isinstance(key, slice):
# -> 2137             return self._get_slice_axis(key, axis=axis)
#    2138
#    2139         if isinstance(key, list):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
# ...

# %%
X=df.iloc[:,[1,2,3,5]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,df1,test_size=0.30,random_state=77)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-665d3a045aa5> in <module>
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(X,df1,test_size=0.30,random_state=77)
#
# NameError: name 'df1' is not defined

# %%
df1=df.iloc[:,0]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,df1,test_size=0.30,random_state=77)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.score(X_train,y_train)
# Out:
# 0.5667349438943141

# %%
polynomial_features=PolynomialFeatures(degree=2)
x_poly=polynomial_features.fit_transform(X)

model=LinearRegression()
model.fit(x_poly,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-b47466697699> in <module>
# ----> 1 polynomial_features=PolynomialFeatures(degree=2)
#       2 x_poly=polynomial_features.fit_transform(X)
#       3
#       4 model=LinearRegression()
#       5 model.fit(x_poly,y)
#
# NameError: name 'PolynomialFeatures' is not defined

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_features=PolynomialFeatures(degree=2)
x_poly=polynomial_features.fit_transform(X)

model=LinearRegression()
model.fit(x_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model=LinearRegression()
model.fit(x_poly,df1)
y_poly_pred=model.predict(x_poly)

# %%
y_poly_pred
# Out:
# array([ 75.82941247,  74.83040071,  73.27966573,  75.52028787,
#         73.12612092,  73.00367615,  78.26082198,  59.42244133,
#         72.20057361,  77.5097301 ,  55.63193276,  75.58095693,
#         57.68218123,  75.90161422,  50.71003907,  55.11867993,
#         56.7544711 ,  80.69446054,  57.01637426,  55.64999403,
#         72.69469404,  75.48452632,  49.76783589,  76.62441289,
#         49.89460026,  73.34586232,  52.56557267,  54.50676371,
#         56.22351517,  78.55833435,  80.38758359,  80.52799464,
#         55.43867176,  52.85538286,  56.61506262,  75.03663796,
#         55.95480178,  74.81517386,  55.32637482,  48.35502047,
#         75.76559354,  74.74339337,  74.92434723,  73.47232328,
#         74.65096602,  45.54866738,  76.86057734,  81.22411685,
#         52.94054336,  54.85937781,  74.18194922,  73.73072923,
#         43.45015319,  53.42160729,  56.47552079,  77.88840051,
#         56.50525468,  52.96960578,  74.77705622,  50.63820305,
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse=np.sqrt(mean_squared_error(y,y_poly_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-3fd65d2a0a64> in <module>
# ----> 1 rmse=np.sqrt(mean_squared_error(y,y_poly_pred))
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
rmse=np.sqrt(mean_squared_error(y,y_poly_pred))

# %%
rmse
# Out:
# 65.81848097774777

# %%
rscore=r2_score(y,y_poly_pred)

# %%
rscore
# Out:
# -17327.28975287258

# %%
model.score(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e841ba68d8ab> in <module>
# ----> 1 model.score(X_train,y_train)
#
# NameError: name 'model' is not defined
